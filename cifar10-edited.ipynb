# %%
import torch
from torchvision.datasets import CIFAR10

# %%
ds = CIFAR10 (root = "data", train =True, download =True)
test_ds = CIFAR10 (root= "data", train=False, download= True)
classes = ['plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:14<00:00, 12142596.18it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified

# %%
print(f" Train datasetda {len(ds)}ta rasm bor.")
print(f" Test datasetda {len(test_ds)}ta rasm bor.")
print(f" CIFAR10 datasetida {len(classes)}ta nom bor.")
# Out:
#  Train datasetda 50000ta rasm bor.
#  Test datasetda 10000ta rasm bor.
#  CIFAR10 datasetida 10ta nom bor.

# %%
data = ds[20000]
len(data)
# Out:
# 2

# %%
type(data[0])
# Out:
# PIL.Image.Image

# %%
type(data[1])
# Out:
# int

# %%
rasm, raqam = data[0], data[1]
print(rasm.size)
print(raqam)
# Out:
# (32, 32)
# 8

# %%
display(rasm)
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
import numpy as np
rasm_array = np.array(rasm)
rasm_array
# Out:
# array([[[ 26,  23,  32],
#         [ 17,  14,  25],
#         [ 13,   9,  24],
#         ...,
#         [ 15,  14,  28],
#         [ 24,  24,  37],
#         [ 22,  21,  34]],
#
#        [[ 20,  17,  26],
#         [ 13,  10,  22],
#         [ 13,   9,  24],
#         ...,
#         [ 19,  17,  35],
#         [ 21,  20,  35],
#         [ 29,  29,  39]],
#
#        [[ 14,  11,  20],
#         [ 13,  10,  21],
#         [ 13,   9,  23],
#         ...,
#         [ 17,  16,  32],
#         [ 25,  24,  38],
#         [ 31,  31,  42]],
#
#        ...,
#
#        [[ 90, 109, 137],
#         [ 34,  64,  95],
#         [ 28,  54,  90],
#         ...,
#         [ 23,  20,  37],
#         [ 16,  13,  30],
#         [  9,   6,  23]],
#
#        [[ 79, 105, 141],
#         [ 58,  96, 139],
#         [ 32,  68, 110],
#         ...,
#         [ 14,  11,  28],
#         [ 16,  13,  30],
#         [ 10,   7,  24]],
#
#        [[128, 157, 196],
#         [ 58,  93, 149],
#         [ 25,  60, 106],
#         ...,
#         [ 13,  10,  27],
#         [ 12,   9,  26],
#         [ 13,  10,  27]]], dtype=uint8)

# %%
from matplotlib import pyplot as plt
plt.imshow(rasm, cmap = "gray" )

# %%
from torchvision import transforms as tfs
tr_ts = tfs.Compose([tfs.ToTensor(),
  tfs.Normalize(0.5, 0.5, 0.5)])



test_ts = tfs.Compose([tfs.ToTensor(),
                       tfs.Normalize(0.5, 0.5, 0.5)])


ds = CIFAR10 (root="data", train= True, transform= tr_ts, download = True)
test_ds = CIFAR10(root= "data", train= False, transform= test_ts, download=True)

classes = ['plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
data = ds[5000]
rasm, raqam = data[0], data[1]
torch.unique(rasm)
# Out:
# tensor([-1.0000, -0.9922, -0.9843, -0.9765, -0.9686, -0.9608, -0.9529, -0.9451,
#         -0.9373, -0.9294, -0.9216, -0.9137, -0.9059, -0.8980, -0.8902, -0.8824,
#         -0.8745, -0.8667, -0.8588, -0.8510, -0.8431, -0.8353, -0.8275, -0.8196,
#         -0.8118, -0.8039, -0.7961, -0.7882, -0.7804, -0.7725, -0.7647, -0.7569,
#         -0.7490, -0.7412, -0.7333, -0.7255, -0.7176, -0.7098, -0.7020, -0.6941,
#         -0.6863, -0.6784, -0.6706, -0.6627, -0.6549, -0.6471, -0.6392, -0.6314,
#         -0.6235, -0.6157, -0.6078, -0.6000, -0.5922, -0.5843, -0.5765, -0.5686,
#         -0.5608, -0.5529, -0.5451, -0.5373, -0.5294, -0.5216, -0.5137, -0.5059,
#         -0.4980, -0.4902, -0.4824, -0.4745, -0.4667, -0.4588, -0.4510, -0.4431,
#         -0.4353, -0.4275, -0.4196, -0.4118, -0.4039, -0.3961, -0.3882, -0.3804,
#         -0.3725, -0.3647, -0.3569, -0.3490, -0.3412, -0.3333, -0.3255, -0.3176,
#         -0.3098, -0.3020, -0.2941, -0.2863, -0.2784, -0.2706, -0.2627, -0.2549,
#         -0.2471, -0.2392, -0.2314, -0.2235, -0.2157, -0.2078, -0.2000, -0.1922,
#         -0.1843, -0.1765, -0.1686, -0.1608, -0.1529, -0.1451, -0.1373, -0.1294,
#         -0.1216, -0.1137, -0.1059, -0.0980, -0.0902, -0.0824, -0.0745, -0.0667,
#         -0.0588, -0.0510, -0.0431, -0.0353, -0.0275, -0.0196, -0.0118, -0.0039,
#          0.0039,  0.0118,  0.0196,  0.0275,  0.0353,  0.0431,  0.0510,  0.0588,
#          0.0667,  0.0745,  0.0824,  0.0902,  0.0980,  0.1059,  0.1137,  0.1216,
#          0.1294,  0.1373,  0.1451,  0.1529,  0.1608,  0.1686,  0.1765,  0.1843,
#          0.1922,  0.2000,  0.2078,  0.2157,  0.2235,  0.2314,  0.2392,  0.2549,
#          0.2627,  0.2706,  0.2784,  0.2863,  0.2941,  0.3098,  0.3176,  0.3333,
#          0.3412,  0.3490,  0.3569,  0.3647,  0.3725,  0.3804,  0.3882,  0.3961,
#          0.4039,  0.4118,  0.4196,  0.4275,  0.4510,  0.4588,  0.4745,  0.4902,
#          0.5059,  0.5216,  0.5294])

# %%
import random

def tensor_2_im(t, t_type = "rgb"):

    gray_tfs = tfs.Compose([tfs.Normalize(mean = [ 0.], std = [1/0.5]), tfs.Normalize(mean = [-0.5], std = [1])])
    # rgb_tfs = tfs.Compose([tfs.Normalize(mean = [ 0., 0., 0. ], std = [ 1/0.229, 1/0.224, 1/0.225 ]), tfs.Normalize(mean = [ -0.485, -0.456, -0.406 ], std = [ 1., 1., 1. ])])
    rgb_tfs = tfs.Compose([tfs.Normalize(mean = [ 0., 0., 0. ], std = [ 1/0.5, 1/0.5, 1/0.5 ]), tfs.Normalize(mean = [ -0.5, -0.5, -0.5 ], std = [ 1., 1., 1. ])])

    invTrans = gray_tfs if t_type == "gray" else rgb_tfs

    return (invTrans(t) * 255).detach().squeeze().cpu().permute(1,2,0).numpy().astype(np.uint8) if t_type == "gray" else (invTrans(t) * 255).detach().cpu().permute(1,2,0).numpy().astype(np.uint8)


def visualize(data, rasmlar_soni, qatorlar, cmap = None, klass_nomlari = None):

    assert cmap in ["rgb", "gray"], "Rasmni oq-qora yoki rangli ekanini aniqlashtirib bering!"
    if cmap == "rgb": cmap = "viridis"

    plt.figure(figsize = (20, 10))
    indekslar = [random.randint(0, len(data) - 1) for _ in range(rasmlar_soni)]
    for idx, indeks in enumerate(indekslar):

        im, gt = data[indeks]
        # Start plot
        plt.subplot(qatorlar, rasmlar_soni // qatorlar, idx + 1)
        if cmap:
            plt.imshow(tensor_2_im(im, cmap), cmap=cmap)
        else:
            plt.imshow(tensor_2_im(im))
        plt.axis('off')
        if klass_nomlari is not None:
            plt.title (klass_nomlari[gt])
        else:
            plt.title(f"GT -> {gt}")

# %%
visualize(data = ds, rasmlar_soni = 30, qatorlar = 5, cmap = 'rgb', klass_nomlari = classes)

# %%
from torch.utils.data import random_split, DataLoader

tr_length = int(len(ds) * 0.8 )
tr_ds, val_ds = random_split(dataset= ds, lengths = [tr_length, len(ds) - tr_length])
print(f"Train datasetda {len(tr_ds)} ta batch bor.")
print(f"Validation datasetda {len(val_ds)} ta batch bor.")
print(f"Train datasetda {len(test_ds)} ta batch bor.")
# Out:
# Train datasetda 40000 ta batch bor.
# Validation datasetda 10000 ta batch bor.
# Train datasetda 10000 ta batch bor.

# %%
bs = 128
tr_dl = DataLoader(dataset = tr_ds, batch_size = bs, shuffle = True, num_workers = 4, drop_last = False) # cpu lar soni
val_dl = DataLoader(dataset = val_ds, batch_size = bs, shuffle = False, num_workers = 4)
test_dl = DataLoader(dataset = test_ds, batch_size = bs, shuffle = False, num_workers = 4)
print(f"Train dataloader {len(tr_dl)}ta batch bor.")
print(f"Validation dataloaderda {len(val_dl)}ta batch bor.")
print(f"Test dataloaderda {len(test_dl)}ta batch bor.")
# Out:
# Train dataloader 313ta batch bor.
# Validation dataloaderda 79ta batch bor.
# Test dataloaderda 79ta batch bor.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
import torch
from torch import nn


class Model(nn.Module):



    def __init__(self, in_chs, out_chs,in_fs, ks,s, p, n_cls) :
        super().__init__()

        self.conv_1 = nn.Conv2d(in_channels=in_chs, out_channels = out_chs, kernel_size=ks, stride= s, padding = p)
        self.conv_2 = nn.Conv2d(in_channels=out_chs, out_channels = out_chs*2, kernel_size=ks, stride= s, padding = p)
        self.conv_3 = nn.Conv2d(in_channels=out_chs*2, out_channels = out_chs*4, kernel_size=ks, stride= s, padding = p)

        self.linear_1 = nn.Linear(in_features=in_fs, out_features= in_fs // 2)
        self.linear_2 = nn.Linear(in_features=in_fs //2 , out_features= n_cls)
        self.act = nn.ReLU()
        self.mp = nn.MaxPool2d(kernel_size =2, stride = 2)


    def forward(self, inp):

      out = self.conv_1(inp)
      out = self.act(out)
      out = self.mp(out)

      out = self.conv_2(out)
      out = self.act(out)
      out = self.mp(out)

      out = self.conv_3(out)
      out = self.act(out)
      out = self.mp(out)

      print(out.shape)

      bs= inp.shape[0]
      out = out.view(bs, -1)

      out= self.linear_1(out)
      out = self.act(out)
      out = self.linear_2(out)

      return out

rasm = torch.rand(1, 3, 32, 32)
model = Model(in_chs = 3, out_chs=8, in_fs= 512 , ks=3 , s=1, p=1, n_cls=10)
model(rasm).shape
# Out:
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 10])

# %%
import torch
inp = torch.rand (1, 3, 32, 32)
model.eval()
model(inp)
# Out:
# torch.Size([1, 32, 4, 4])
# tensor([[ 0.0186,  0.0175,  0.0297, -0.0006,  0.0614,  0.0091,  0.0151,  0.0617,
#           0.0030, -0.0469]], grad_fn=<AddmmBackward0>)

# %%
epochs = 20
device = "cpu"
model.to(device)
model.train()
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params = model.parameters(), lr = 0.001)

# %%
from tqdm import tqdm
import os

best_acc = 0
prefix = "CIFAR10"




for epoch in range (epochs):

  model.train()
  print(f" { epoch + 1} - epoch jarayonlari boshlandi")

  epoch_loss, epoch_acc, total = 0, 0, 0

  for i , batch in tqdm(enumerate(tr_dl)):
    rasm, gts = batch
    rasm , gts = rasm.to(device), gts.to(device)
    total += rasm.shape[0]


    preds = model(rasm)
    loss = loss_fn(preds, gts)
    pred_cls = torch.argmax(preds.data, dim = 1)
    epoch_acc += (pred_cls == gts).sum().item()
    epoch_loss += loss.item()

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  print("\n ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
  print(f"{epoch +1 }- epoch train jarayoni natijalari :")
  print(f" {epoch +1}- epochdagi train loss     -> {(epoch_loss / len(tr_dl)):.3f}")
  print(f" {epoch +1}- epochdagi train accuracy     -> {(epoch_acc / total):.3f}")



  model.eval()
  with torch.no_grad():
      val_epoch_loss, val_epoch_acc, val_total = 0, 0, 0

      for idx, batch in tqdm(enumerate(val_dl)):
        rasm, gts = batch
        rasm, gts = rasm.to(device),  gts.to(device)
        val_total += rasm.shape[0]

        preds = model(rasm)
        loss = loss_fn(preds, gts)
        pred_cls = torch.argmax(preds.data, dim =1)

        val_epoch_acc += (pred_cls == gts).sum().item()
        val_epoch_loss += loss.item()

        val_acc = val_epoch_acc / val_total



  print("\n ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
  print(f"{epoch +1 }- epoch validation jarayoni natijalari :")
  print(f" {epoch +1}- epochdagi validation loss     -> {(val_epoch_loss / len(val_dl)):.3f}")
  print(f" {epoch +1}- epochdagi validation accuracy     -> {(val_acc):.3f}")


  if val_acc > best_acc:
          os.makedirs("modellar", exist_ok=True)
          best_acc = val_acc
          torch.save(model.state_dict(), f"modellar/{prefix}_best_model.pth")
# Out:
#  1 - epoch jarayonlari boshlandi
# 3it [00:00,  7.44it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 5it [00:00,  9.96it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 9it [00:00, 13.18it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 13it [00:01, 14.37it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 17it [00:01, 15.33it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 21it [00:01, 15.22it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 25it [00:01, 15.23it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 29it [00:02, 15.67it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 31it [00:02, 12.69it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 33it [00:02, 10.89it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 35it [00:02, 10.96it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 37it [00:03, 10.06it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 40it [00:03,  9.20it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 43it [00:03,  9.35it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 44it [00:03,  9.09it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 48it [00:04,  9.17it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 49it [00:04,  8.88it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 53it [00:04,  8.91it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 54it [00:04,  8.58it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 57it [00:05,  8.83it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 61it [00:05,  9.35it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 65it [00:05, 12.75it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 69it [00:06, 14.33it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 73it [00:06, 15.27it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 77it [00:06, 15.40it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 79it [00:06, 15.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 81it [00:07, 11.53it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 85it [00:07,  9.60it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 87it [00:07, 10.79it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 91it [00:07, 13.01it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 93it [00:08, 10.86it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 97it [00:08,  9.04it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 101it [00:09, 11.51it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 103it [00:09, 11.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 107it [00:09,  8.34it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 111it [00:10, 11.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 115it [00:10, 13.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 119it [00:10, 14.66it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 123it [00:10, 15.10it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 127it [00:11, 15.32it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 131it [00:11, 15.82it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 135it [00:11, 16.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 139it [00:11, 15.95it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 143it [00:12, 16.04it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 147it [00:12, 16.26it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 151it [00:12, 16.17it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 155it [00:12, 15.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 157it [00:12, 15.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 161it [00:13, 15.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 165it [00:13, 15.56it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 169it [00:13, 15.91it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 173it [00:14, 15.70it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 177it [00:14, 16.10it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 181it [00:14, 16.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 185it [00:14, 16.04it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 189it [00:15, 15.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 193it [00:15, 15.94it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 197it [00:15, 16.06it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 201it [00:15, 14.47it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 203it [00:16, 12.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 207it [00:16, 10.45it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 209it [00:16,  9.80it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 211it [00:16,  9.91it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 213it [00:17,  9.18it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 215it [00:17,  8.81it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 216it [00:17,  8.92it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 218it [00:17,  9.15it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 221it [00:18,  9.11it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 223it [00:18,  9.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 225it [00:18,  8.46it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 228it [00:18,  9.41it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 229it [00:18,  8.94it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 233it [00:19, 11.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 237it [00:19, 13.68it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 241it [00:19, 14.93it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 245it [00:19, 15.77it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 249it [00:20, 15.88it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 253it [00:20, 15.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 257it [00:20, 15.47it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 261it [00:20, 15.69it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 265it [00:21, 15.89it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 269it [00:21, 15.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 275it [00:21, 16.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 277it [00:21, 15.92it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 281it [00:22, 15.58it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 285it [00:22, 15.73it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 289it [00:22, 15.95it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 293it [00:23, 15.93it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 297it [00:23, 15.57it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 301it [00:23, 15.71it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 305it [00:23, 15.99it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 308it [00:23, 17.72it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 313it [00:24, 12.96it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([64, 32, 4, 4])
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 1- epoch train jarayoni natijalari :
#  1- epochdagi train loss     -> 1.382
#  1- epochdagi train accuracy     -> 0.502
# 4it [00:00, 11.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 9it [00:00, 16.33it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 15it [00:00, 19.82it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 18it [00:01, 19.54it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 24it [00:01, 21.20it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 30it [00:01, 21.28it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 33it [00:01, 21.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 39it [00:02, 21.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 45it [00:02, 21.38it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 48it [00:02, 21.61it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 54it [00:02, 21.83it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 60it [00:03, 21.89it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 63it [00:03, 21.23it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 69it [00:03, 21.41it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 76it [00:03, 26.54it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 79it [00:03, 20.97it/s]
# torch.Size([16, 32, 4, 4])
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 1- epoch validation jarayoni natijalari :
#  1- epochdagi validation loss     -> 1.334
#  1- epochdagi validation accuracy     -> 0.518
#  2 - epoch jarayonlari boshlandi
# 1it [00:00,  3.51it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 4it [00:00,  8.49it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 8it [00:00, 12.46it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 10it [00:00, 12.46it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 14it [00:01,  9.95it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 16it [00:01, 10.27it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 18it [00:01,  9.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 19it [00:01,  9.01it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 23it [00:02,  9.29it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 25it [00:02,  8.90it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 27it [00:02,  9.17it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 29it [00:03, 10.11it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 32it [00:03,  8.89it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 34it [00:03,  9.30it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 36it [00:03,  9.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 38it [00:04,  9.24it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 39it [00:04,  9.04it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 43it [00:04, 11.02it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 47it [00:04, 13.25it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 51it [00:04, 14.17it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 55it [00:05, 14.84it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 59it [00:05, 14.84it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 63it [00:05, 15.22it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 67it [00:06, 15.54it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 71it [00:06, 15.79it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 75it [00:06, 15.55it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 79it [00:06, 15.86it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 83it [00:07, 15.76it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 87it [00:07, 15.93it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 91it [00:07, 15.65it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 95it [00:07, 15.81it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 99it [00:08, 15.93it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 103it [00:08, 15.65it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 107it [00:08, 15.22it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 111it [00:08, 15.15it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 115it [00:09, 15.35it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 119it [00:09, 15.53it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 123it [00:09, 15.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 125it [00:09, 15.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 129it [00:10, 15.47it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 133it [00:10, 15.54it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 137it [00:10, 15.53it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 141it [00:10, 15.37it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 145it [00:11, 15.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 149it [00:11, 15.55it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 153it [00:11, 15.61it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 157it [00:11, 15.58it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 161it [00:12, 15.76it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 165it [00:12, 15.74it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 169it [00:12, 15.84it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 173it [00:12, 15.91it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 177it [00:13, 16.04it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 181it [00:13, 16.08it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 185it [00:13, 15.91it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 189it [00:13, 15.52it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 193it [00:14, 15.80it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 197it [00:14, 15.30it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 199it [00:14, 12.67it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 203it [00:15, 10.68it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 205it [00:15,  9.83it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 207it [00:15,  9.23it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 209it [00:15,  9.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 211it [00:15,  9.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 213it [00:16,  8.75it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 215it [00:16,  8.77it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 219it [00:16,  9.28it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 220it [00:16,  8.86it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 224it [00:17,  8.97it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 226it [00:17,  9.18it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 229it [00:17, 10.44it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 231it [00:17, 11.35it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 235it [00:18, 13.42it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 239it [00:18, 14.61it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 243it [00:18, 14.80it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 245it [00:18, 15.04it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 249it [00:19, 15.18it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 253it [00:19, 15.50it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 257it [00:19, 15.73it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 261it [00:19, 15.92it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 265it [00:20, 15.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 269it [00:20, 15.54it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 273it [00:20, 15.80it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 277it [00:20, 15.89it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 281it [00:21, 15.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 285it [00:21, 15.54it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 289it [00:21, 15.85it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 293it [00:21, 15.79it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 297it [00:22, 15.22it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 301it [00:22, 15.67it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 305it [00:22, 15.77it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 311it [00:23, 19.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 313it [00:23, 13.53it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([64, 32, 4, 4])
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 2- epoch train jarayoni natijalari :
#  2- epochdagi train loss     -> 1.258
#  2- epochdagi train accuracy     -> 0.549
# 4it [00:00, 11.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 9it [00:00, 16.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 12it [00:00, 18.91it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 18it [00:01, 18.41it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 21it [00:01, 19.31it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 27it [00:01, 20.57it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 33it [00:01, 21.85it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 39it [00:02, 20.44it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 42it [00:02, 21.49it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 48it [00:02, 20.94it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 54it [00:02, 21.95it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 57it [00:03, 17.37it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 62it [00:03, 18.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 65it [00:03, 19.77it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 71it [00:03, 21.08it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 79it [00:03, 19.98it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([16, 32, 4, 4])
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 2- epoch validation jarayoni natijalari :
#  2- epochdagi validation loss     -> 1.228
#  2- epochdagi validation accuracy     -> 0.559
#  3 - epoch jarayonlari boshlandi
# 1it [00:00,  3.51it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 5it [00:00,  8.58it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 7it [00:00,  7.90it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 9it [00:01,  8.07it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 11it [00:01,  8.25it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 13it [00:01,  8.31it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 15it [00:01,  8.23it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 17it [00:02,  8.06it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 19it [00:02,  8.15it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 21it [00:02,  8.35it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 23it [00:02,  8.38it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 25it [00:03,  8.46it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 27it [00:03,  9.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 28it [00:03,  8.29it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 32it [00:03, 10.44it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 36it [00:04, 12.80it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 40it [00:04, 13.97it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 44it [00:04, 14.79it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 48it [00:04, 15.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 52it [00:05, 14.92it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 56it [00:05, 15.33it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 60it [00:05, 15.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 64it [00:05, 15.50it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 68it [00:06, 14.97it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 72it [00:06, 15.32it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 76it [00:06, 15.45it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 80it [00:06, 15.34it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 84it [00:07, 15.12it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 88it [00:07, 15.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 92it [00:07, 15.63it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 96it [00:07, 15.18it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 98it [00:08, 15.06it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 102it [00:08, 15.09it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 106it [00:08, 15.50it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 110it [00:08, 15.47it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 114it [00:09, 15.65it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 118it [00:09, 15.44it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 122it [00:09, 15.75it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 126it [00:09, 15.53it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 130it [00:10, 15.32it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 134it [00:10, 15.13it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 138it [00:10, 15.37it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 142it [00:10, 15.33it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 146it [00:11, 15.51it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 150it [00:11, 15.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 154it [00:11, 15.56it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 158it [00:12, 14.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 160it [00:12,  8.47it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 164it [00:12, 10.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 166it [00:12, 10.95it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 170it [00:13, 13.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 174it [00:13, 14.10it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 178it [00:13, 14.63it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 180it [00:13, 12.18it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 182it [00:14, 11.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 186it [00:14, 11.12it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 188it [00:14, 10.60it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 192it [00:15,  9.59it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 195it [00:15,  9.29it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 197it [00:15,  9.33it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 198it [00:15,  8.80it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 202it [00:16,  9.29it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 204it [00:16,  9.61it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 207it [00:16,  8.98it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 209it [00:17,  9.07it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 211it [00:17,  9.17it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 214it [00:17, 10.40it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 216it [00:17, 11.50it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 220it [00:17, 13.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 224it [00:18, 14.46it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 228it [00:18, 14.98it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 232it [00:18, 14.95it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 236it [00:19, 15.04it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 240it [00:19, 15.08it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 244it [00:19, 15.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 248it [00:19, 15.27it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 252it [00:20, 15.32it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 256it [00:20, 14.40it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 258it [00:20, 14.63it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 262it [00:20, 14.69it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 266it [00:21, 15.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 270it [00:21, 15.21it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 274it [00:21, 15.41it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 278it [00:21, 14.85it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 282it [00:22, 15.11it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 286it [00:22, 15.55it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 290it [00:22, 15.54it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 294it [00:22, 14.86it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 298it [00:23, 15.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 302it [00:23, 15.29it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 306it [00:23, 16.16it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 313it [00:23, 13.05it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([64, 32, 4, 4])
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 3- epoch train jarayoni natijalari :
#  3- epochdagi train loss     -> 1.156
#  3- epochdagi train accuracy     -> 0.588
# 3it [00:00,  9.03it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 9it [00:00, 17.32it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 14it [00:00, 18.44it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 19it [00:01, 20.33it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 22it [00:01, 20.98it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 28it [00:01, 21.08it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 31it [00:01, 20.98it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 37it [00:01, 20.84it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 43it [00:02, 21.49it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 46it [00:02, 20.88it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 52it [00:02, 21.24it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 55it [00:02, 20.31it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 61it [00:03, 21.07it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 64it [00:03, 21.47it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 69it [00:03, 18.15it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 73it [00:03, 16.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 76it [00:04, 19.17it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([16, 32, 4, 4])
# 79it [00:04, 18.98it/s]
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 3- epoch validation jarayoni natijalari :
#  3- epochdagi validation loss     -> 1.157
#  3- epochdagi validation accuracy     -> 0.589
#  4 - epoch jarayonlari boshlandi
# 1it [00:00,  1.70it/s]
# torch.Size([128, 32, 4, 4])
# 2it [00:00,  2.96it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 5it [00:01,  5.87it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 7it [00:01,  7.77it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 8it [00:01,  7.48it/s]
# torch.Size([128, 32, 4, 4])
# 10it [00:01,  8.20it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 12it [00:01,  8.56it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 17it [00:02, 10.42it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 19it [00:02, 11.56it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 23it [00:02, 12.94it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 25it [00:02, 13.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 29it [00:03, 14.26it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 33it [00:03, 14.95it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 37it [00:03, 15.08it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 41it [00:03, 15.02it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 45it [00:04, 14.99it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 49it [00:04, 15.05it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 53it [00:04, 14.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 55it [00:04, 13.73it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 59it [00:05, 14.38it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 63it [00:05, 14.76it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 67it [00:05, 14.96it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 69it [00:05, 14.55it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 73it [00:06, 15.02it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 77it [00:06, 15.12it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 81it [00:06, 14.82it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 85it [00:06, 14.70it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 89it [00:07, 14.78it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 93it [00:07, 15.23it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 97it [00:07, 15.34it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 101it [00:08, 15.03it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 105it [00:08, 14.97it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 107it [00:08, 14.74it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 111it [00:08, 14.81it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 115it [00:08, 14.82it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 119it [00:09, 15.15it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 123it [00:09, 15.41it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 127it [00:09, 15.06it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 131it [00:10, 14.99it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 135it [00:10, 15.38it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 139it [00:10, 15.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 143it [00:10, 15.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 147it [00:11, 14.84it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 151it [00:11, 15.21it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 155it [00:11, 15.13it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 159it [00:11, 15.35it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 163it [00:12, 15.20it/s]
# ...
# torch.Size([128, 32, 4, 4])
# 53it [00:04, 10.85it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 57it [00:04, 11.60it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 59it [00:04, 11.03it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 61it [00:04, 11.68it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 65it [00:05, 10.90it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 67it [00:05, 11.32it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 71it [00:05, 11.33it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 74it [00:05, 14.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 79it [00:06, 12.70it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([16, 32, 4, 4])
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 19- epoch validation jarayoni natijalari :
#  19- epochdagi validation loss     -> 1.067
#  19- epochdagi validation accuracy     -> 0.680
#  20 - epoch jarayonlari boshlandi
# 1it [00:00,  2.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 6it [00:00,  8.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 8it [00:01,  9.47it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 12it [00:01, 11.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 14it [00:01, 11.65it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 16it [00:01, 12.34it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 20it [00:02, 12.08it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 24it [00:02, 12.38it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 26it [00:02, 12.72it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 30it [00:02, 12.68it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 32it [00:02, 12.55it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 36it [00:03, 12.75it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 38it [00:03, 12.13it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 42it [00:03, 12.51it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 44it [00:03, 12.10it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 46it [00:04, 12.31it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 50it [00:04, 12.26it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 54it [00:04, 12.28it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 56it [00:04, 12.32it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 60it [00:05, 12.58it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 64it [00:05, 12.80it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 66it [00:05, 12.41it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 70it [00:06, 12.71it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 72it [00:06, 12.52it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 76it [00:06, 12.68it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 78it [00:06, 12.49it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 82it [00:07, 12.79it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 84it [00:07, 12.53it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 88it [00:07, 12.51it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 90it [00:07, 13.24it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 94it [00:07, 12.61it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 96it [00:08, 12.51it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 100it [00:08, 12.70it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 102it [00:08, 12.41it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 106it [00:08, 12.81it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 108it [00:09, 12.68it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 112it [00:09, 12.79it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 114it [00:09, 12.76it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 118it [00:09, 12.86it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 120it [00:10, 12.56it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 124it [00:10, 12.61it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 126it [00:10, 11.60it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 128it [00:10, 10.02it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 131it [00:11,  9.21it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 133it [00:11,  9.12it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 135it [00:11,  8.99it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 137it [00:11,  8.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 139it [00:12,  8.27it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 141it [00:12,  7.83it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 143it [00:12,  7.94it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 146it [00:13,  7.69it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 147it [00:13,  8.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 150it [00:13,  7.84it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 152it [00:13,  7.43it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 154it [00:14,  7.66it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 156it [00:14,  7.87it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 158it [00:14,  8.03it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 160it [00:14,  7.89it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 162it [00:15,  7.88it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 164it [00:15,  8.41it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 166it [00:15,  8.20it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 168it [00:15,  8.08it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 170it [00:16,  9.54it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 174it [00:16, 11.57it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 176it [00:16, 11.71it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 178it [00:16, 12.04it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 182it [00:16, 12.19it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 186it [00:17, 12.79it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 188it [00:17, 12.52it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 192it [00:17, 12.83it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 194it [00:17, 12.07it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 198it [00:18, 12.49it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 200it [00:18, 12.08it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 204it [00:18, 12.68it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 206it [00:18, 12.34it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 208it [00:19, 12.18it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 212it [00:19, 12.55it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 214it [00:19, 12.51it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 218it [00:19, 12.78it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 220it [00:20, 12.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 224it [00:20, 12.65it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 226it [00:20, 12.68it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 230it [00:20, 12.88it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 232it [00:20, 12.38it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 236it [00:21, 12.84it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 238it [00:21, 12.48it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 242it [00:21, 12.79it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 244it [00:21, 12.62it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 248it [00:22, 12.61it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 250it [00:22, 12.47it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 254it [00:22, 12.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 256it [00:22, 12.49it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 260it [00:23, 12.52it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 262it [00:23, 12.37it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 266it [00:23, 12.73it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 268it [00:23, 12.50it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 272it [00:24, 12.42it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 274it [00:24, 12.57it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 278it [00:24, 12.80it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 280it [00:24, 12.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 284it [00:25, 12.53it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 286it [00:25, 12.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 290it [00:25, 12.71it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 292it [00:25, 12.26it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 294it [00:25, 12.13it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 296it [00:26, 10.72it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 300it [00:26, 10.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 302it [00:26,  9.24it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 303it [00:26,  8.97it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 307it [00:27, 10.26it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 309it [00:27, 11.39it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 313it [00:27, 13.21it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([64, 32, 4, 4])
# 313it [00:27, 11.25it/s]
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 20- epoch train jarayoni natijalari :
#  20- epochdagi train loss     -> 0.399
#  20- epochdagi train accuracy     -> 0.861
# 2it [00:00,  3.86it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 5it [00:00,  7.93it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 7it [00:01,  8.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 11it [00:01, 10.25it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 13it [00:01, 10.35it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 15it [00:01, 11.21it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 19it [00:02, 10.83it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 21it [00:02, 11.88it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 25it [00:02, 12.93it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 29it [00:02, 14.83it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 33it [00:03, 15.15it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 37it [00:03, 16.14it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 41it [00:03, 16.31it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 44it [00:03, 17.29it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 48it [00:03, 16.11it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 52it [00:04, 16.76it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 56it [00:04, 16.53it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 60it [00:04, 16.34it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 64it [00:04, 16.20it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 68it [00:05, 16.64it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 73it [00:05, 19.42it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# 79it [00:05, 14.00it/s]
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([128, 32, 4, 4])
# torch.Size([16, 32, 4, 4])
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 20- epoch validation jarayoni natijalari :
#  20- epochdagi validation loss     -> 1.103
#  20- epochdagi validation accuracy     -> 0.681

# %%
rasm, gts = next(iter(test_dl))


model.eval ()
preds = []
images = []
lbls = []

for rasm, gt in zip(rasm, gts):
  rasm, gt = rasm.to(device), gt.to(device)
  pred = model(rasm.unsqueeze(0))
  pred_class = torch.argmax(pred, dim =1)
  images.append(rasm)
  lbls.append(gt)
  preds.append(pred_class)
print(len(preds))
# Out:
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# torch.Size([1, 32, 4, 4])
# 128

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

# %%
import random

def tensor_2_im(t, t_type = "rgb"):

    gray_tfs = tfs.Compose([tfs.Normalize(mean = [ 0.], std = [1/0.5]), tfs.Normalize(mean = [-0.5], std = [1])])
    # rgb_tfs = tfs.Compose([tfs.Normalize(mean = [ 0., 0., 0. ], std = [ 1/0.229, 1/0.224, 1/0.225 ]), tfs.Normalize(mean = [ -0.485, -0.456, -0.406 ], std = [ 1., 1., 1. ])])
    rgb_tfs = tfs.Compose([tfs.Normalize(mean = [ 0., 0., 0. ], std = [ 1/0.5, 1/0.5, 1/0.5 ]), tfs.Normalize(mean = [ -0.5, -0.5, -0.5 ], std = [ 1., 1., 1. ])])

    invTrans = gray_tfs if t_type == "gray" else rgb_tfs

    return (invTrans(t) * 255).detach().squeeze().cpu().permute(1,2,0).numpy().astype(np.uint8) if t_type == "gray" else (invTrans(t) * 255).detach().cpu().permute(1,2,0).numpy().astype(np.uint8)


def visualize(data, rasmlar_soni, qatorlar, cmap = None, klass_nomlari = None):

    assert cmap in ["rgb", "gray"], "Rasmni oq-qora yoki rangli ekanini aniqlashtirib bering!"
    if cmap == "rgb": cmap = "viridis"

    plt.figure(figsize = (20, 10))
    indekslar = [random.randint(0, len(data) - 1) for _ in range(rasmlar_soni)]
    for idx, indeks in enumerate(indekslar):

        im, gt = data[indeks]
        # Start plot
        plt.subplot(qatorlar, rasmlar_soni // qatorlar, idx + 1)
        if cmap:
            plt.imshow(tensor_2_im(im, cmap), cmap=cmap)
        else:
            plt.imshow(tensor_2_im(im))
        plt.axis('off')
        if klass_nomlari is not None:
            plt.title (klass_nomlari[gt])
        else:
            plt.title(f"GT -> {gt}")

# %%
from PIL import Image

rasm = Image.open("33.jpeg")
test_ts = tfs.Compose([tfs.Resize((32,32)),
    tfs.Grayscale(num_output_channels=3),
                       tfs.ToTensor(),
                       tfs.Normalize(0.5, 0.5)])
tensor_im = test_ts(rasm)
tensor_im.shape
# Out:
# torch.Size([3, 32, 32])

# %%
pred = model(tensor_im.unsqueeze(dim=0))
pred_class = torch.argmax(pred, dim = 1)
plt.imshow(tensor_2_im(tensor_im, t_type= "rgb"))
plt.axis('off')
plt.title  (classes[pred_class.item()])
# Out:
# torch.Size([1, 32, 4, 4])
# Text(0.5, 1.0, 'car')

# %%
print(classes[9])
# Out:
# truck

# %%
from PIL import Image

rasm = Image.open("bird.webp")
test_ts = tfs.Compose([tfs.Resize((32,32)),
    tfs.Grayscale(num_output_channels=3),
                       tfs.ToTensor(),
                       tfs.Normalize(0.5, 0.5)])
tensor_im = test_ts(rasm)
tensor_im.shape
# Out:
# torch.Size([3, 32, 32])

# %%
pred = model(tensor_im.unsqueeze(dim=0))
pred_class = torch.argmax(pred, dim = 1)
plt.imshow(tensor_2_im(tensor_im, t_type= "grey"))
plt.axis('off')
plt.title (classes[pred_class.item()])
# Out:
# torch.Size([1, 32, 4, 4])
# Text(0.5, 1.0, 'cat')

# %%
print(classes[2])
# Out:
# bird

# %%
 from PIL import Image

rasm = Image.open("111 - Copy.jpeg")
test_ts = tfs.Compose([tfs.Resize((32,32)),
    tfs.Grayscale(num_output_channels=3),
                       tfs.ToTensor(),
                       tfs.Normalize(0.5, 0.5)])
tensor_im = test_ts(rasm)
tensor_im.shape
# Out:
# torch.Size([3, 32, 32])

# %%
pred = model(tensor_im.unsqueeze(dim=0))
pred_class = torch.argmax(pred, dim = 1)
plt.imshow(tensor_2_im(tensor_im, t_type= "grey"))
plt.axis('off')
plt.title (classes[pred_class.item()])
# Out:
# torch.Size([1, 32, 4, 4])
# Text(0.5, 1.0, 'bird')

# %%
print(classes[2])
# Out:
# bird

# %%
 from PIL import Image

rasm = Image.open("ship2.jpeg")
test_ts = tfs.Compose([tfs.Resize((32,32)),
    tfs.Grayscale(num_output_channels=3),
                       tfs.ToTensor(),
                       tfs.Normalize(0.5, 0.5)])
tensor_im = test_ts(rasm)
tensor_im.shape
# Out:
# torch.Size([3, 32, 32])

# %%
pred = model(tensor_im.unsqueeze(dim=0))
pred_class = torch.argmax(pred, dim = 1)
plt.imshow(tensor_2_im(tensor_im, t_type= "grey"))
plt.axis('off')
plt.title (classes[pred_class.item()])
# Out:
# torch.Size([1, 32, 4, 4])
# Text(0.5, 1.0, 'ship')

# %%
print(classes[2])
# Out:
# deer
